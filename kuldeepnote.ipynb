-- %%
use catalog kuldeep_catalog;
use schema testschema;

-- %%
GRANT SELECT ON CATALOG kuldeep_catalog TO `boa2`;

-- %%
create streaming table kulstream11 as select * FROM STREAM read_files("/Volumes/boa_bricks/default/kulvol/route/",
    format => 'CSV'
    );

-- %%
create  or replace table kulexample(id int,constraint kul expect(id>0) on violation drop row)

-- %%
insert into kulexample values(0)

-- %%
select * from kulexample
